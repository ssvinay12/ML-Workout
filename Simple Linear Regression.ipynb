# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %% [markdown]
# Now we have all our libraries in Jupyter notebook- now lets setup our plotting parameters
#
# ### we want matplotlib inline with our juypter Notebook
#
# we use
#
# #### %matplotlib inline

# %%
# %matplotlib inline
### lets set our dimentions for data visualization to 10 Inches wide and 8 inches wide

rcParams['figure.figsize'] = 10,8

# %%
# we will just create some synthetic data to do some LinearRegression - we will create a variable called rooms and assign some random 
### generator

rooms = 2*np.random.rand(100, 1)+3
rooms[1:10]
# Out:
# array([[3.79087066],
#        [3.58155746],
#        [4.75430891],
#        [4.60650577],
#        [3.35081677],
#        [3.21039594],
#        [3.32220341],
#        [4.4208422 ],
#        [4.34583325]])

# %%
price = 265 + 6*rooms +abs(np.random.randn(100, 1))
price[1:10]
# Out:
# array([[288.40785889],
#        [287.13910084],
#        [294.1464199 ],
#        [293.41217729],
#        [285.77023832],
#        [285.99131811],
#        [285.27821089],
#        [292.92248087],
#        [291.72563685]])

# %%
plt.plot(room, price, )   # ('r^' - This specifies point plot should be generated instead of default plot )
plt.xlabel( '# of Rooms, 2022 Average')
plt.ylabel('2022 Average Home, 1000s USD')
plt.show()

# %%
plt.plot(room, price, 'r^')   # ('r^' - This specifies point plot should be generated instead of default plot )
plt.xlabel( '# of Rooms, 2022 Average')
plt.ylabel('2022 Average Home, 1000s USD')
plt.show()

# %%
x = rooms
y = price

LinReg = LinearRegression()
LinReg.fit(x,y)
print(LinReg.intercept_, LinReg.coef_)
# Out:
# [266.6241432] [[5.79382537]]

# %% [markdown]
# ####  SImple Algebra
#
#  . y = mx + b
#  here from above equation
#  b = intercept = 266.6241432
#
#  Estimated Coefficients
#
#  . LinReg.coef_ = 5.79382537 Estimated coeffiecient for the terms in the linear Regression problem

# %% [markdown]
# NOw lets look how well our model performed to do that

# %%
print(LinReg.score(x,y))
# Out:
# 0.970736374765325

# %% [markdown]
# #### The score function returns the coeffiecient of determination which is the R**2 of the prediction
